# %% [markdown]
# Projeto Final Semantix
#
# Aluno: Pedro Augusto Ramos

# %% [markdown]
# Neste projeto iremos baixar as tabelas com os dados do site do Ministério da Saúde brasileiro  https://covid.saude.gov.br/
# sobre a epidemia de Covid-19.
#
# A proposta é utilizar Spark com linguagem pyspark sql e reproduzir os resumos das informação mostradas no site, como por exemplo número total de casos confirmados, casos recuperados, novos casos, taxa de letalidade, etc.

# %% [markdown]
# Importação dos Pacotes:

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import functions as f

# %% [markdown]
# Criado o diretório "projeto-final" no hdfs

# %%
# !hdfs dfs -mkdir -p /user/pedro/projeto-final

# %% [markdown]
# Foi realizada a transferência dos arquivos sobre casos de Covid-19 no Brasil que foram baixados localmente do site do ministério da saúde do governo brasileiro para o HDFS no terminal dentro do container namenode. Podemos conferir abaixo:

# %%
# !hdfs dfs -ls /user/pedro/projeto-final/dados
# Out:
# Found 7 items
# -rw-r--r--   3 root supergroup       6148 2022-08-06 22:29 /user/pedro/projeto-final/dados/.DS_Store
# -rw-r--r--   3 root supergroup   62493275 2022-08-06 22:29 /user/pedro/projeto-final/dados/HIST_PAINEL_COVIDBR_2020_Parte1_03ago2022.csv
# -rw-r--r--   3 root supergroup   76520606 2022-08-06 22:29 /user/pedro/projeto-final/dados/HIST_PAINEL_COVIDBR_2020_Parte2_03ago2022.csv
# -rw-r--r--   3 root supergroup   91120853 2022-08-06 22:29 /user/pedro/projeto-final/dados/HIST_PAINEL_COVIDBR_2021_Parte1_03ago2022.csv
# -rw-r--r--   3 root supergroup   93414239 2022-08-06 22:29 /user/pedro/projeto-final/dados/HIST_PAINEL_COVIDBR_2021_Parte2_03ago2022.csv
# -rw-r--r--   3 root supergroup   91807916 2022-08-06 22:29 /user/pedro/projeto-final/dados/HIST_PAINEL_COVIDBR_2022_Parte1_03ago2022.csv
# -rw-r--r--   3 root supergroup   17330062 2022-08-06 22:29 /user/pedro/projeto-final/dados/HIST_PAINEL_COVIDBR_2022_Parte2_03ago2022.csv

# %% [markdown]
# Criamos um dataframe para ler as tabelas e entendermos seu schema e estrutura

# %%
df_tabela_covid = spark.read.csv("/user/pedro/projeto-final/dados/*.csv", sep = ";", header = "true", inferSchema = "true")

# %% [markdown]
# Podemos agora indentificar as colunas e seus schemas

# %%
df_tabela_covid.printSchema()
# Out:
# root
#  |-- regiao: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- municipio: string (nullable = true)
#  |-- coduf: integer (nullable = true)
#  |-- codmun: integer (nullable = true)
#  |-- codRegiaoSaude: integer (nullable = true)
#  |-- nomeRegiaoSaude: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- semanaEpi: integer (nullable = true)
#  |-- populacaoTCU2019: integer (nullable = true)
#  |-- casosAcumulado: decimal(10,0) (nullable = true)
#  |-- casosNovos: integer (nullable = true)
#  |-- obitosAcumulado: integer (nullable = true)
#  |-- obitosNovos: integer (nullable = true)
#  |-- Recuperadosnovos: integer (nullable = true)
#  |-- emAcompanhamentoNovos: integer (nullable = true)
#  |-- interior/metropolitana: integer (nullable = true)

# %% [markdown]
# Número de linhas da tabela

# %%
df_tabela_covid.count()
# Out:
# 4833208

# %% [markdown]
# Otimizar todos os dados do hdfs para uma tabela Hive particionada por município

# %%
df_tabela_covid.write.mode("overwrite").partitionBy("municipio").saveAsTable("tabela_covid")

# %% [markdown]
# Verificando a tabela particionada no hive por município:

# %%
# !hdfs dfs -ls /user/hive/warehouse/tabela_covid
# Out:
# Found 5299 items
# -rw-r--r--   2 root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/_SUCCESS
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abadia de Goiás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abadia dos Dourados
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abadiânia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abaetetuba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abaeté
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abaiara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abaré
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abatiá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abaíra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abdon Batista
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abel Figueiredo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abelardo Luz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abre Campo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abreu e Lima
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Abreulândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acaiaca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acajutiba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acarape
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acaraú
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acará
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acauã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aceguá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acopiara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acorizal
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acrelândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Acreúna
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Adamantina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Adelândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Adolfo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Adrianópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Adustina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Afogados da Ingazeira
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Afonso Bezerra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Afonso Cláudio
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Afonso Cunha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Afrânio
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Afuá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Agrestina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Agricolândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Agrolândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Agronômica
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aguanil
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aguaí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Agudo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Agudos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Agudos do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aguiar
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aguiarnópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aimorés
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aiquara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aiuaba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aiuruoca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ajuricaba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alagoa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alagoa Grande
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alagoa Nova
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alagoinha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alagoinha do Piauí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alagoinhas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alambari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Albertina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alcantil
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alcinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alcobaça
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alcântara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alcântaras
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aldeias Altas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alecrim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alegre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alegrete
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alegrete do Piauí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alegria
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alenquer
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alexandria
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alexânia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alfenas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alfredo Chaves
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alfredo Marcondes
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alfredo Vasconcelos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alfredo Wagner
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Algodão de Jandaíra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alhandra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aliança
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aliança do Tocantins
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Almadina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Almas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Almeirim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Almenara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Almino Afonso
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Almirante Tamandaré
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Almirante Tamandaré do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aloândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alpercata
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alpestre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alpinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alta Floresta
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alta Floresta D%27Oeste
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altair
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altamira
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altamira do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altamira do Paraná
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altaneira
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alterosa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altinho
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Alegre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Alegre do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Alegre do Pindaré
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Alegre dos Parecis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Araguaia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Bela Vista
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Boa Vista
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Caparaó
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Feliz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Garças
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Horizonte
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Jequitibá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Longá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Paraguai
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Paraná
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Paraíso
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Paraíso de Goiás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Parnaíba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Piquiri
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Rio Doce
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Rio Novo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Santo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto Taquari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alto do Rodrigues
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Altônia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alumínio
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvarenga
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvarães
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvinlândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvorada
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvorada D%27Oeste
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvorada de Minas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvorada do Gurguéia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvorada do Norte
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Alvorada do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Além Paraíba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amajari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amambai
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amaporã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amapá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amapá do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amaraji
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amaral Ferrador
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amaralina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amarante
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amarante do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amargosa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amaturá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Americana
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Americano do Brasil
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ametista do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amontada
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amorinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amparo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amparo de São Francisco
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amparo do Serra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ampére
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Amélia Rodrigues
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=América Dourada
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Américo Brasiliense
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Américo de Campos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anadia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anagé
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anahy
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anajatuba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anajás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Analândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anamã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ananindeua
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ananás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anapu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anapurus
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anastácio
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anaurilândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anchieta
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Andaraí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Andirá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Andorinha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Andradas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Andradina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Andrelândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=André da Rocha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angatuba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angelim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angelina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angelândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angical
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angical do Piauí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angico
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angicos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angra dos Reis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anguera
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Angélica
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anhanguera
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anhembi
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anhumas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anicuns
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anita Garibaldi
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anitápolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anori
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anta Gorda
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antonina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antonina do Norte
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Almeida
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Cardoso
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Carlos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Dias
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Gonçalves
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio João
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Martins
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Olinto
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Prado
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Antônio Prado de Minas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anápolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Anísio de Abreu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aparecida
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aparecida d%27Oeste
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aparecida de Goiânia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aparecida do Rio Doce
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aparecida do Rio Negro
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aparecida do Taboado
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aperibé
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apiacá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apiacás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apiaí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apicum-Açu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apiúna
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apodi
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aporá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aporé
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apuarema
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apucarana
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apuiarés
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Apuí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aquidabã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aquidauana
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aquiraz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arabutã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aracaju
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aracati
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aracatu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araci
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aracitaba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aracoiaba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aracruz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aragarças
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aragoiânia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aragominas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguacema
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguaiana
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguainha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguanã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguapaz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguatins
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguaçu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araguaína
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araioses
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aral Moreira
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aramari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arambaré
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arame
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aramina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arandu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arantina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arapeí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arapiraca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arapoema
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araponga
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arapongas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araporã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arapoti
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araputanga
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arapuá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arapuã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araquari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araranguá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araraquara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araras
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ararendá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araricá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araripe
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araripina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araruama
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araruna
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arataca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aratiba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aratuba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aratuípe
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araucária
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arauá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araxá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçagi
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçariguama
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçatuba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçaí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçoiaba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçoiaba da Serra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçuaí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araçás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Araújos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arceburgo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arco-Íris
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arcos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arcoverde
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areado
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areal
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arealva
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areia Branca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areia de Baraúnas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areial
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areias
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Areiópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arenápolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arenópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Argirita
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aricanduva
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arinos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aripuanã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ariquemes
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ariranha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ariranha do Ivaí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Armazém
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Armação dos Búzios
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arneiroz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aroazes
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aroeiras
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aroeiras do Itaim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arraial
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arraial do Cabo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arraias
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arroio Grande
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arroio Trinta
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arroio do Meio
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arroio do Padre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arroio do Sal
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arroio do Tigre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arroio dos Ratos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Artur Nogueira
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aruanã
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arujá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arvoredo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arvorezinha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Arês
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ascurra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aspásia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Assaré
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Assaí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Assis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Assis Brasil
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Assis Chateaubriand
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Assunção
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Assunção do Piauí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Astolfo Dutra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Astorga
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Atalaia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Atalaia do Norte
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Atalanta
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ataléia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Atibaia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Atílio Vivacqua
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Augustinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Augusto Corrêa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Augusto Pestana
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Augusto de Lima
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aurelino Leal
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Auriflama
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aurilândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aurora
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aurora do Pará
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aurora do Tocantins
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Autazes
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Avanhandava
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Avaré
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Avaí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Aveiro
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Avelino Lopes
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Avelinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Axixá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Axixá do Tocantins
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Açailândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Açu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Açucena
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Babaçulândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Bacabal
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Bacabeira
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Bacuri
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Bacurituba
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Bady Bassitt
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baependi
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Bagre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Bagé
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baianópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baixa Grande
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baixa Grande do Ribeiro
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baixio
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baixo Guandu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baião
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Balbinos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baldim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Baliza
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Balneário Arroio do Silva
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Balneário Barra do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Balneário Camboriú
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Balneário Gaivota
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Balneário Pinhal
# ...
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Veranópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Verdejante
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Verdelândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vereda
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Veredinha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vermelho Novo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vertente do Lério
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vertentes
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Verê
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Veríssimo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vespasiano
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vespasiano Corrêa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Viadutos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Viamão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Viana
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vianópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vicente Dutra
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vicentina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vicentinópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Victor Graeff
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vicência
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vidal Ramos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Videira
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vieiras
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vieirópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vigia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Bela da Santíssima Trindade
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Boa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Flor
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Flores
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Lângaro
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Maria
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Nova do Piauí
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Nova do Sul
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Nova dos Martírios
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Pavão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Propício
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Rica
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Valério
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vila Velha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vilhena
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vinhedo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Viradouro
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Virgem da Lapa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Virginópolis
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Virgolândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Virgínia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Virmond
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Visconde do Rio Branco
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Viseu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vista Alegre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vista Alegre do Alto
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vista Alegre do Prata
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vista Gaúcha
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vista Serrana
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitor Meireles
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitorino
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitorino Freire
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória Brasil
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória da Conquista
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória das Missões
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória de Santo Antão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória do Jari
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória do Mearim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Vitória do Xingu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Viçosa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Viçosa do Ceará
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Volta Grande
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Volta Redonda
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Votorantim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Votuporanga
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea Alegre
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea Branca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea Grande
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea Nova
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea Paulista
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea da Palma
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea da Roça
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Várzea do Poço
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Wagner
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Wall Ferraz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Wanderley
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Wanderlândia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Wenceslau Braz
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Wenceslau Guimarães
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Westfália
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Witmarsum
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xambioá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xambrê
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xangri-lá
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xanxerê
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xapuri
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xavantina
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xaxim
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xexéu
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xinguara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Xique-Xique
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Zabelê
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Zacarias
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Zortéa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=Zé Doca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:14 /user/hive/warehouse/tabela_covid/municipio=__HIVE_DEFAULT_PARTITION__
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Azul do Norte
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Boa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Branca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Clara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Comprida
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Doce
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Doce do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Doce do Norte
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Fria
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Fria de Goiás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Limpa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Nova
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Preta
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Água Santa
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas Belas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas Formosas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas Frias
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas Lindas de Goiás
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas Mornas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas Vermelhas
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas da Prata
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas de Chapecó
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas de Lindóia
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas de Santa Bárbara
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águas de São Pedro
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Águia Branca
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Álvares Florence
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Álvares Machado
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Álvaro de Carvalho
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Áurea
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Ângulo
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Érico Cardoso
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Óbidos
# drwxr-xr-x   - root supergroup          0 2022-08-07 03:13 /user/hive/warehouse/tabela_covid/municipio=Óleo

# %% [markdown]
# Abaixo, o campo 'data' contém informação sobre horário que não é relevante. Vamos criar um campo apenas com data (yyyy-MM-dd) usando a função substring

# %%
df_tabela_covid.select('data').show(10)
# Out:
# +-------------------+
# |               data|
# +-------------------+
# |2021-07-01 00:00:00|
# |2021-07-02 00:00:00|
# |2021-07-03 00:00:00|
# |2021-07-04 00:00:00|
# |2021-07-05 00:00:00|
# |2021-07-06 00:00:00|
# |2021-07-07 00:00:00|
# |2021-07-08 00:00:00|
# |2021-07-09 00:00:00|
# |2021-07-10 00:00:00|
# +-------------------+
# only showing top 10 rows

# %%
df_tabela = df_tabela_covid.withColumn("data_", substring("data", 1,10))

# %%
df_tabela.select('data_').show(5)
# Out:
# +----------+
# |     data_|
# +----------+
# |2021-07-01|
# |2021-07-02|
# |2021-07-03|
# |2021-07-04|
# |2021-07-05|
# +----------+
# only showing top 5 rows

# %%
df_tabela = df_tabela.drop('data')

# %% [markdown]
# Abaixo, visualizamos as últimas linhas de registros com a função 'monolitically_increasing_id()'

# %%
last_row = df_tabela.withColumn("index", monotonically_increasing_id())
last_row.orderBy(desc("index")).drop("index").show(1)
# Out:
# +------------+------+---------+-----+------+--------------+----------------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+----------+
# |      regiao|estado|municipio|coduf|codmun|codRegiaoSaude| nomeRegiaoSaude|semanaEpi|populacaoTCU2019|casosAcumulado|casosNovos|obitosAcumulado|obitosNovos|Recuperadosnovos|emAcompanhamentoNovos|interior/metropolitana|     data_|
# +------------+------+---------+-----+------+--------------+----------------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+----------+
# |Centro-Oeste|    DF| Brasília|   53|530010|         53001|DISTRITO FEDERAL|       31|         3015268|        832270|       494|          11821|          0|            null|                 null|                     1|2022-08-03|
# +------------+------+---------+-----+------+--------------+----------------+---------+----------------+--------------+----------+---------------+-----------+----------------+---------------------+----------------------+----------+
# only showing top 1 row

# %% [markdown]
# Criando as 3 visualizações pelo spark.sql com os dados enviados para o hdfs

# %% [markdown]
# A última atualização da pesquisa na tabela foi em 03 de agosto de 2021.
# Vale ressaltar que o site é dinâmico e pude observar que são feitas atualizações quase diárias nos dados.

# %%
ultima_data = "2021-08-03"
painel = df_tabela.where((df_tabela.regiao == 'Brasil') & (df_tabela.data_ == ultima_data))

# %% [markdown]
# Visualização 1: Casos Recuperados e Casos em acompanhamento

# %%
recuperados_painel = painel.select(painel['Recuperadosnovos'].alias('Casos_Recuperados'),\
                           painel['emAcompanhamentoNovos'].alias('Em_Acompanhamento'))
recuperados_painel.show()
# Out:
# +-----------------+-----------------+
# |Casos_Recuperados|Em_Acompanhamento|
# +-----------------+-----------------+
# |         18746865|           680520|
# +-----------------+-----------------+

# %% [markdown]
# Visualizacão 2: Casos Confirmados: Acumulado, Casos Novos, Incidência

# %% [markdown]
# De acordo com Wikipedia, o cálculo de incidência epidemiológica é calculado pelos número de novos casos (aqui representado pelo campo 'casosAcumulado') em dado local (Brasil) e período, dividido pela populacão de risco do mesmo local e período (aqui o campo 'PopulacaoTCU2019' = 210.147.125). Observando o site do governo, podemos observar que o campo incidência está descrito como "Incidência/100mil hab." Ou seja, o resultado desta divisão deve ser multiplicado por 100.000 habitantes.

# %%
confirmados_painel = painel.select(painel['casosAcumulado'].alias('Acumulados'),\
                     painel['casosNovos'].alias('Casos_Novos'),\
                     (f.round(painel['casosAcumulado']/painel['PopulacaoTCU2019']*100000,1)).alias('Incidência')) 
confirmados_painel.show()
# Out:
# +----------+-----------+----------+
# |Acumulados|Casos_Novos|Incidência|
# +----------+-----------+----------+
# |  19985817|      32316|    9510.4|
# +----------+-----------+----------+

# %% [markdown]
# Visualização 3: Óbitos Acumulados, Letalidade, Casos Novos e Mortalidade
#
# De acordo com a Wikipedia, a taxa de letalidade (L) ou coeficiente de letalidade é a proporção entre o número de mortes por uma doença e o número total de doentes que sofrem dessa doença, ao longo de um determinado período de tempo. É geralmente expressa em percentagem.
#
# Já a taxa de mortalidade ou coeficiente de mortalidade é um índice demográfico que reflete o número de mortes registradas, aqui representado pelos óbitos acumulados dividido pela população total. No caso desta tabela, o site do governo mostra que essa taxa é calculada por 100.000 habitantes.

# %%
obitos_painel = painel.select(painel['obitosAcumulado'].alias('Óbitos_Acumulados'),\
                              painel['obitosNovos'].alias('Casos_Novos'),\
                        (f.round(painel['obitosAcumulado']/painel['casosAcumulado']*100,1)).alias('Letalidade'),\
                        (f.round(painel['obitosAcumulado']/painel['PopulacaoTCU2019']*100000,1)).alias('Mortalidade'))
obitos_painel.show()
# Out:
# +-----------------+-----------+----------+-----------+
# |Óbitos_Acumulados|Casos_Novos|Letalidade|Mortalidade|
# +-----------------+-----------+----------+-----------+
# |           558432|       1209|       2.8|      265.7|
# +-----------------+-----------+----------+-----------+

# %% [markdown]
# 4. Salvar a primeira visualização como tabela Hive

# %%
recuperados_painel.write.mode("overwrite").saveAsTable("recuperados_covid")

# %% [markdown]
# Vamos checar:

# %%
# !hdfs dfs -ls /user/hive/warehouse/recuperados_covid
# Out:
# Found 2 items
# -rw-r--r--   2 root supergroup          0 2022-08-08 00:59 /user/hive/warehouse/recuperados_covid/_SUCCESS
# -rw-r--r--   2 root supergroup        679 2022-08-08 00:59 /user/hive/warehouse/recuperados_covid/part-00000-2ac6f9a4-1751-43ec-aaa9-964c77bb6001-c000.snappy.parquet

# %% [markdown]
# 5. Salvar a segunda visualização com formato parquet e compressão snappy
#    Por padrão, uma tabela Hive é salva já com formato parquet e compressão snappy

# %%
confirmados_painel.write.mode("overwrite").saveAsTable("confirmados_covid")

# %% [markdown]
# Vamos checar:

# %%
# !hdfs dfs -ls /user/hive/warehouse/confirmados_covid
# Out:
# Found 2 items
# -rw-r--r--   2 root supergroup          0 2022-08-08 01:05 /user/hive/warehouse/confirmados_covid/_SUCCESS
# -rw-r--r--   2 root supergroup       1003 2022-08-08 01:05 /user/hive/warehouse/confirmados_covid/part-00000-1fa1c1fb-8269-470b-b67f-620a6736d51d-c000.snappy.parquet
